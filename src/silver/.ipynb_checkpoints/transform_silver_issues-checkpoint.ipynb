# %% [markdown]
# ##### <font color="green"> Import libraries and set the file location for reading. </font>

# %%
import pandas as pd

file = '../../data/bronze/bronze_issues.parquet'

# %% [markdown]
# ##### <font color="green"> Read file and store bronze table </font>

# %%
bronze_archive = pd.read_parquet(file)
df = pd.DataFrame(bronze_archive)

df
# Out:
#             id issue_type    status priority  \
# 0    JIRA-0001        Bug      Open      Low
# 1    JIRA-0002        Bug  Resolved     High
# 2    JIRA-0003      Story      Open     High
# 3    JIRA-0004      Story      Done     High
# 4    JIRA-0005       Task  Resolved   Medium
# ..         ...        ...       ...      ...
# 995  JIRA-0996       Task      Done      Low
# 996  JIRA-0997       Task      Open   Medium
# 997  JIRA-0998       Task  Resolved      Low
# 998  JIRA-0999       Task      Done     High
# 999  JIRA-1000        Bug      Open      Low
#
#                                               assignee  \
# 0    [{'email': 'gionni.lucio@fasttrack.com', 'id':...
# 1    [{'email': 'francinne@fasttrack.com', 'id': 'u...
# 2    [{'email': 'adyna@fasttrack.com', 'id': 'u005'...
# 3    [{'email': 'francinne@fasttrack.com', 'id': 'u...
# 4    [{'email': 'francinne@fasttrack.com', 'id': 'u...
# ..                                                 ...
# 995  [{'email': 'francinne@fasttrack.com', 'id': 'u...
# 996  [{'email': 'guilherme@fasttrack.com', 'id': 'u...
# 997  [{'email': 'matheus.malta@fasttrack.com', 'id'...
# 998  [{'email': 'adyna@fasttrack.com', 'id': 'u005'...
# 999  [{'email': 'francinne@fasttrack.com', 'id': 'u...
#
#                                             timestamps
# 0    [{'created_at': '2025-08-02T14:55:05Z', 'resol...
# 1    [{'created_at': '2025-03-09T12:39:26Z', 'resol...
# 2    [{'created_at': '2025-06-30T17:06:48Z', 'resol...
# 3    [{'created_at': '2025-11-22T20:24:58Z', 'resol...
# 4    [{'created_at': '2025-01-06T01:08:44Z', 'resol...
# ..                                                 ...
# 995  [{'created_at': '2026-02-30T25:61:00Z', 'resol...
# 996  [{'created_at': '2026-02-30T25:61:00Z', 'resol...
# 997  [{'created_at': '2026-02-30T25:61:00Z', 'resol...
# 998  [{'created_at': '2026-02-30T25:61:00Z', 'resol...
# 999  [{'created_at': '2026-02-30T25:61:00Z', 'resol...
#
# [1000 rows x 6 columns]

# %% [markdown]
# ##### <font color="green"> Explode the columns that are the assignee list and timestamps, and expand the dictionaries into columns. </font>

# %%
df_silver = df.copy()

df_silver = df_silver.explode('assignee')
df_silver = df_silver.explode('timestamps')

assignee_colunms = pd.json_normalize(df_silver['assignee'])
timestamps_colunms = pd.json_normalize(df_silver['timestamps'])

# %% [markdown]
# ##### <font color="green"> Merge all columns </font>

# %%
df = pd.concat(
    [
        df_silver.drop(columns=['assignee', 'timestamps']),
        assignee_colunms,
        timestamps_colunms
    ],
    axis=1
)

# %% [markdown]
# ##### <font color="green"> Handling non-standard records to enable string conversion to date and time. </font>

# %%
df['created_at'] = df['created_at'].replace('2026-02-30T25:61:00Z','2026-02-28T23:59:59Z')
df['resolved_at'] = df['resolved_at'].replace('not_a_date',None)

# %% [markdown]
# ##### <font color="green"> String conversion to UTC date and time </font>

# %%
df['created_at'] = pd.to_datetime(df['created_at'], utc=True)
df['resolved_at'] = pd.to_datetime(df['resolved_at'], utc=True)

# %% [markdown]
# ##### <font color="green"> Rename the column names </font>

# %%
df.columns = ['issue_id','issue_type','status','priority','assignee_email','assignee_id','assignee_name','created_at','resolved_at']
df.head(5)
# Out:
#     issue_id issue_type    status priority              assignee_email  \
# 0  JIRA-0001        Bug      Open      Low  gionni.lucio@fasttrack.com
# 1  JIRA-0002        Bug  Resolved     High     francinne@fasttrack.com
# 2  JIRA-0003      Story      Open     High         adyna@fasttrack.com
# 3  JIRA-0004      Story      Done     High     francinne@fasttrack.com
# 4  JIRA-0005       Task  Resolved   Medium     francinne@fasttrack.com
#
#   assignee_id assignee_name                created_at  \
# 0        u002  Gionni Lucio 2025-08-02 14:55:05+00:00
# 1        u004     Francinne 2025-03-09 12:39:26+00:00
# 2        u005         Adyna 2025-06-30 17:06:48+00:00
# 3        u004     Francinne 2025-11-22 20:24:58+00:00
# 4        u004     Francinne 2025-01-06 01:08:44+00:00
#
#                 resolved_at
# 0                       NaT
# 1 2025-03-10 10:39:26+00:00
# 2                       NaT
# 3 2025-11-23 07:24:58+00:00
# 4 2025-01-07 09:08:44+00:00

# %% [markdown]
# ##### <font color="green"> Save silver table </font>

# %%
df.to_parquet("../../data/silver/silver_issues.parquet", index=False)

# %% [markdown]
# ##### <font color="red"> Space reserved for exploring and understanding the data. </font>

# %%
df['issue_type'].value_counts().head(5)
# Out:
# issue_type
# Story    359
# Task     343
# Bug      298
# Name: count, dtype: int64

# %%
df['status'].value_counts().head(5)
# Out:
# status
# Done        417
# Resolved    394
# Open        189
# Name: count, dtype: int64

# %%
df['priority'].value_counts().head(5)
# Out:
# priority
# Low       347
# Medium    335
# High      318
# Name: count, dtype: int64

# %%
SLA = df['resolved_at'] - df['created_at']
SLA
# Out:
# 0                 NaT
# 1     0 days 22:00:00
# 2                 NaT
# 3     0 days 11:00:00
# 4     1 days 08:00:00
#             ...
# 995               NaT
# 996               NaT
# 997               NaT
# 998               NaT
# 999               NaT
# Length: 1000, dtype: timedelta64[ns]

# %%
df['email'].value_counts().head(5)
# Out:
# email
# gionni.lucio@fasttrack.com     213
# francinne@fasttrack.com        212
# guilherme@fasttrack.com        194
# adyna@fasttrack.com            193
# matheus.malta@fasttrack.com    188
# Name: count, dtype: int64

# %%
df['email'].value_counts().head(5)
